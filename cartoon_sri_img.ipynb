# %%
import cv2
import numpy as np
from google.colab import files

# %%
def read_file(filename):
  img = cv2.imread(filename)
  cv2_imshow(img)
  return img

# %%
upload = files.upload()
filename = next(iter(uploaded))
img = read_file(filename)
# Out:
#      <input type="file" id="files-9b3902f3-8046-42c4-ab8c-a68279eee481" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b3902f3-8046-42c4-ab8c-a68279eee481">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving business-woman.jpg to business-woman (10).jpg
# <PIL.Image.Image image mode=RGB size=410x399 at 0x7FDCBED51860>

# %%
def edge_mask(img, line_size, blur_value):
  blue = cv2.cvtColor(img, cv2.COLOR_BGR2BLUE)
  blue_blur = cv2.medianBlur(gray, blur_value)
  return edge

# %%
line_size = 7
blur_value = 7
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=410x399 at 0x7FDCBED51A20>

# %%
blurred = cv2.bilateralFilter(img, d=12, sigmaColor=200,sigmaSpace=102)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=RGB size=410x399 at 0x7FDCBED51A58>

# %%
cartoon = cv2.bitwise_and(blurred, blurred, mask=edges)
cv2_imshow(cartoon)
# Out:
# <PIL.Image.Image image mode=RGB size=410x399 at 0x7FDCBED51320>
